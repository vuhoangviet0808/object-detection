# %%
# !pip install fiftyone
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 92.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.9/110.9 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 75.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 943.0/943.0 kB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.5 MB/s eta 0:00:00
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.3/981.3 kB 17.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 58.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 44.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# # Download data

# %%
import fiftyone as fo
import fiftyone.zoo as foz

splits = ['train', 'test', 'validation']
for split in splits:
  dataset = foz.load_zoo_dataset(
      "open-images-v7",
      split=split,
      label_types=["detections"],
      classes=["Alpaca"],
      max_samples=1000,
      dataset_name="open-images-alpaca"
  )
# Out:
# ...
# INFO:fiftyone.zoo.datasets:Downloading split 'train' to '/root/fiftyone/open-images-v7/train' if necessary
# ...
# INFO:fiftyone.utils.openimages:Downloading 'https://storage.googleapis.com/openimages/2018_04/train/train-images-boxable-with-rotation.csv' to '/root/fiftyone/open-images-v7/train/metadata/image_ids.csv'
#  100% |██████|    4.8Gb/4.8Gb [15.6s elapsed, 0s remaining, 324.1Mb/s]
# INFO:eta.core.utils: 100% |██████|    4.8Gb/4.8Gb [15.6s elapsed, 0s remaining, 324.1Mb/s]
# ...
# INFO:fiftyone.utils.openimages:Downloading 'https://storage.googleapis.com/openimages/v5/class-descriptions-boxable.csv' to '/root/fiftyone/open-images-v7/train/metadata/classes.csv'
# ...
# INFO:fiftyone.utils.openimages:Downloading 'https://storage.googleapis.com/openimages/2018_04/bbox_labels_600_hierarchy.json' to '/tmp/tmpmh7cbkyp/metadata/hierarchy.json'
# ...

# %% [markdown]
# # Convert data to appropriate data format YOLO

# %%
import os
import pandas as pd
from tqdm import tqdm
from PIL import Image

alpaca_id = '/m/0pcr'

output_dir = '/root/fiftyone/open-images-v7/train'
images_dir = os.path.join(output_dir, 'data')
labels_dir = os.path.join(output_dir, 'labels')

os.makedirs(labels_dir, exist_ok=True)
csv_file_path = os.path.join(labels_dir, 'detections.csv')
detections_df = pd.read_csv(csv_file_path)
detections_df = detections_df[detections_df['LabelName'] == alpaca_id]

image_filenames = detections_df['ImageID'].unique()

for img_filename in tqdm(image_filenames):
    detections = detections_df[(detections_df['ImageID'] == img_filename)]

    img_path = os.path.join(images_dir, img_filename)


    filename_without_extension = os.path.splitext(img_filename)[0]

    label_filename = os.path.join(labels_dir, filename_without_extension + '.txt')

    with open(label_filename, 'w') as label_file:
        first_line = True
        for _, row in detections.iterrows():
            xmin, ymin, xmax, ymax = row['XMin'], row['YMin'], row['XMax'], row['YMax']

            x_center = (xmin + xmax) / 2
            y_center = (ymin + ymax) / 2
            width = xmax - xmin
            height = ymax - ymin

            x_center_normalized = x_center
            y_center_normalized = y_center
            width_normalized = width
            height_normalized = height

            class_id = 0


            if not first_line:
                label_file.write("\n")


            label_file.write(f"{class_id} {x_center_normalized} {y_center_normalized} {width_normalized} {height_normalized}")

            first_line = False
os.remove(csv_file_path)
# Out:
# 100%|██████████| 452/452 [00:00<00:00, 713.53it/s]

# %%
alpaca_id = '/m/0pcr'

output_dir = '/root/fiftyone/open-images-v7/test'
images_dir = os.path.join(output_dir, 'data')
labels_dir = os.path.join(output_dir, 'labels')


os.makedirs(labels_dir, exist_ok=True)
csv_file_path = os.path.join(labels_dir, 'detections.csv')
detections_df = pd.read_csv(csv_file_path)
detections_df = detections_df[detections_df['LabelName'] == alpaca_id]

image_filenames = detections_df['ImageID'].unique()

for img_filename in tqdm(image_filenames):
    detections = detections_df[(detections_df['ImageID'] == img_filename)]


    img_path = os.path.join(images_dir, img_filename)


    # from PIL import Image
    # with Image.open(img_path) as img:
    #     img_width, img_height = img.size


    filename_without_extension = os.path.splitext(img_filename)[0]

    label_filename = os.path.join(labels_dir, filename_without_extension + '.txt')

    with open(label_filename, 'w') as label_file:
        first_line = True
        for _, row in detections.iterrows():
            xmin, ymin, xmax, ymax = row['XMin'], row['YMin'], row['XMax'], row['YMax']


            x_center = (xmin + xmax) / 2
            y_center = (ymin + ymax) / 2
            width = xmax - xmin
            height = ymax - ymin

            x_center_normalized = x_center  # / img_width
            y_center_normalized = y_center  # / img_height
            width_normalized = width  # / img_width
            height_normalized = height  # / img_height

            class_id = 0

            if not first_line:
                label_file.write("\n")

            label_file.write(f"{class_id} {x_center_normalized} {y_center_normalized} {width_normalized} {height_normalized}")

            first_line = False
os.remove(csv_file_path)
# Out:
# 100%|██████████| 72/72 [00:00<00:00, 1353.74it/s]

# %%
alpaca_id = '/m/0pcr'

output_dir = '/root/fiftyone/open-images-v7/validation'
images_dir = os.path.join(output_dir, 'data')
labels_dir = os.path.join(output_dir, 'labels')


os.makedirs(labels_dir, exist_ok=True)
csv_file_path = os.path.join(labels_dir, 'detections.csv')
detections_df = pd.read_csv(csv_file_path)
detections_df = detections_df[detections_df['LabelName'] == alpaca_id]

image_filenames = detections_df['ImageID'].unique()

for img_filename in tqdm(image_filenames):
    detections = detections_df[(detections_df['ImageID'] == img_filename)]

    img_path = os.path.join(images_dir, img_filename)


    from PIL import Image
    with Image.open(img_path+'.jpg') as img:
        img_width, img_height = img.size


    filename_without_extension = os.path.splitext(img_filename)[0]

    label_filename = os.path.join(labels_dir, filename_without_extension + '.txt')

    with open(label_filename, 'w') as label_file:
        first_line = True
        for _, row in detections.iterrows():
            xmin, ymin, xmax, ymax = row['XMin'], row['YMin'], row['XMax'], row['YMax']

            x_center = (xmin + xmax) / 2
            y_center = (ymin + ymax) / 2
            width = xmax - xmin
            height = ymax - ymin

            x_center_normalized = x_center  # / img_width
            y_center_normalized = y_center  # / img_height
            width_normalized = width  # / img_width
            height_normalized = height  # / img_height

            class_id = 0

            if not first_line:
                label_file.write("\n")

            label_file.write(f"{class_id} {x_center_normalized} {y_center_normalized} {width_normalized} {height_normalized}")

            first_line = False
os.remove(csv_file_path)
# Out:
# 100%|██████████| 27/27 [00:00<00:00, 143.48it/s]

# %% [markdown]
# # Train Model

# %%
import ultralytics
print(ultralytics.__version__)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 8.3.112

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 177MB/s]

# %%
train_results = model.train(
    data="/config.yaml",
    epochs=10,
    imgsz=640,
    device='cpu'
)
# Out:
# Ultralytics 8.3.112 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %% [markdown]
# # Test model

# %%
results = model("/root/fiftyone/open-images-v7/validation/images/0cb5cae66bb9c4cd.jpg")
results[0].show()
# Out:
# image 1/1 /root/fiftyone/open-images-v7/validation/images/0cb5cae66bb9c4cd.jpg: 480x640 2 alpacas, 178.0ms
# Speed: 6.0ms preprocess, 178.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
path = model.export(format="onnx")
# Out:
# Ultralytics 8.3.112 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
#
# PyTorch: starting from 'runs/detect/train4/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 235.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 248.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 279.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 188.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 280.0 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 11.0s, installed 3 packages: ['onnx>=1.12.0', 'onnxslim', 'onnxruntime']
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ...

# %%
# Save and download model
import shutil
from google.colab import files
shutil.make_archive('train_results', 'zip', '/content/runs/detect/train4')

files.download('train_results.zip')

# %%
metrics = model.val()
# Out:
# Ultralytics 8.3.112 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1819.9±618.0 MB/s, size: 404.9 KB)
# val: Scanning /root/fiftyone/open-images-v7/validation/labels.cache... 27 images, 0 backgrounds, 0 corrupt: 100%|██████████| 27/27 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:06<00:00,  3.03s/it]
#                    all         27         35      0.734      0.789      0.824      0.626
# Speed: 1.6ms preprocess, 195.5ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs/detect/train42

# %%
results = model.predict(
    source="/root/fiftyone/open-images-v7/test/images",
    save=True,
    imgsz=640,
    device='cpu'
)
# Out:
# image 1/72 /root/fiftyone/open-images-v7/test/images/01ad3ff1d94eb557.jpg: 448x640 5 alpacas, 171.3ms
# image 2/72 /root/fiftyone/open-images-v7/test/images/053608552d63f724.jpg: 480x640 2 alpacas, 194.1ms
# image 3/72 /root/fiftyone/open-images-v7/test/images/075e8ff2794191fa.jpg: 512x640 1 alpaca, 201.5ms
# image 4/72 /root/fiftyone/open-images-v7/test/images/0889d6e03b2c4ecc.jpg: 640x480 1 alpaca, 177.0ms
# image 5/72 /root/fiftyone/open-images-v7/test/images/09e382a83978039b.jpg: 480x640 3 alpacas, 160.9ms
# image 6/72 /root/fiftyone/open-images-v7/test/images/0a5e8d559aa5d680.jpg: 512x640 1 alpaca, 198.8ms
# image 7/72 /root/fiftyone/open-images-v7/test/images/0b2a2c061ef16759.jpg: 640x640 2 alpacas, 234.6ms
# image 8/72 /root/fiftyone/open-images-v7/test/images/0ea961cbe041f639.jpg: 448x640 3 alpacas, 151.6ms
# image 9/72 /root/fiftyone/open-images-v7/test/images/127968dbb456d863.jpg: 448x640 1 alpaca, 162.3ms
# ...

# %%
import shutil
from google.colab import files
shutil.make_archive('test_results', 'zip', '/content/runs/detect/train43')

files.download('test_results.zip')
